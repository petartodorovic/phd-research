# %% [markdown]
# ## Example Notebook of Luminescence Curve Generation Usage

# %% [markdown]
# ### Importing Packages and Modules

# %%
import os
import numpy as np
import pandas as pd
from LuminescenceCurveGeneration import IdealLuminescence as il

# %% [markdown]
# ### Testing Imported IdealLuminescence Module
#
# - alias as il, and test the Luminescence spectra generation

# %%
spectra = il.LuminescenceSpectra(center_wv=430, num_points=1000)  # Creates spectra at 475nm
df = spectra.generate_spectra()  # Generate the data
r1, r2 = spectra.calculate_roots()  # Get FWHM points
spectra.plot_spectra(r1, r2, save_fig=False)
# Out:
# Generating spectra at 430 nm with FWHM of 25 nm
